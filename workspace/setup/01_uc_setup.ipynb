# %%
# %run ../common/01_config

# %%
# %run ../common/02_adls_connection

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
USE CATALOG realtimedatabrickhybrid;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS realtime_pipeline_silver;

# %%
# %run ../batch/bronze_to_silver_batch

# %%
silver_batch_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("realtimedatabrickhybrid.realtime_pipeline_silver.online_retail")

# %%
# %run ../stream/bronze_to_silver_stream

# %%
stream_silver_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("realtimedatabrickhybrid.realtime_pipeline_silver.stream_orders")

# %%
# %sql

SELECT COUNT(*) AS batch_count
FROM realtimedatabrickhybrid.realtime_pipeline_silver.online_retail;

# %%
# %sql
SELECT COUNT(*) AS stream_count
FROM realtimedatabrickhybrid.realtime_pipeline_silver.stream_orders;

# %%
# %sql
SELECT * 
FROM realtimedatabrickhybrid.realtime_pipeline_silver.online_retail
LIMIT 10;

# %%
# %sql
SELECT * 
FROM realtimedatabrickhybrid.realtime_pipeline_silver.stream_orders
LIMIT 10;
